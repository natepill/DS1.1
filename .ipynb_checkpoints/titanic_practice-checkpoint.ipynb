# %%
def add(x,y):
    return x+y

print(add(34,55))
# Out:
# 89

# %%
import pandas as pd

df = pd.read_csv("titanic.csv")
df.head(10)

len(df[(df["Sex"] == "female") & (df["Survived"] == 1)])
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 15            16         1       2
# 19            20         1       3
# 22            23         1       3
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 39            40         1       3
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 52            53         1       1
# 53            54         1       2
# 56            57         1       2
# 58            59         1       2
# 61            62         1       1
# 66            67         1       2
# 68            69         1       3
# ...
